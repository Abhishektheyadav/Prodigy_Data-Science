# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
T_data=pd.read_csv("/content/drive/MyDrive/Prodigy Datasets/Task 4/twitter_training.csv")
T_data.head(10)
# Out:
#      id  game_titles sentiments  \
# 0  2401  Borderlands   Positive
# 1  2401  Borderlands   Positive
# 2  2401  Borderlands   Positive
# 3  2401  Borderlands   Positive
# 4  2401  Borderlands   Positive
# 5  2401  Borderlands   Positive
# 6  2402  Borderlands   Positive
# 7  2402  Borderlands   Positive
# 8  2402  Borderlands   Positive
# 9  2402  Borderlands   Positive
#
#                                                 text  Unnamed: 4  Unnamed: 5  \
# 0  im getting on borderlands and i will murder yo...         NaN         NaN
# 1  I am coming to the borders and I will kill you...         NaN         NaN
# 2  im getting on borderlands and i will kill you ...         NaN         NaN
# 3  im coming on borderlands and i will murder you...         NaN         NaN
# 4  im getting on borderlands 2 and i will murder ...         NaN         NaN
# 5  im getting into borderlands and i can murder y...         NaN         NaN
# ...

# %%
T_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74682 entries, 0 to 74681
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           74682 non-null  int64
#  1   game_titles  74682 non-null  object
#  2   sentiments   74682 non-null  object
#  3   text         73996 non-null  object
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 4.6+ MB

# %%
T_data.describe()
# Out:
#                  id  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# count  74682.000000         0.0         0.0         0.0         0.0
# mean    6432.586165         NaN         NaN         NaN         NaN
# std     3740.427870         NaN         NaN         NaN         NaN
# min        1.000000         NaN         NaN         NaN         NaN
# 25%     3195.000000         NaN         NaN         NaN         NaN
# 50%     6422.000000         NaN         NaN         NaN         NaN
# 75%     9601.000000         NaN         NaN         NaN         NaN
# max    13200.000000         NaN         NaN         NaN         NaN

# %%
T_data.isna().sum()
# Out:
# id                 0
# game_titles        0
# sentiments         0
# text             686
# Unnamed: 4     74682
# Unnamed: 5     74682
# Unnamed: 6     74682
# Unnamed: 7     74682
# dtype: int64

# %%
T_data.isna().sum()
# Out:
# id                 0
# game_titles        0
# sentiments         0
# text             686
# Unnamed: 4     74682
# Unnamed: 5     74682
# Unnamed: 6     74682
# Unnamed: 7     74682
# dtype: int64

# %% [markdown]
# 2. **EDA**

# %%
T_data.head(4)
# Out:
#      id  game_titles sentiments  \
# 0  2401  Borderlands   Positive
# 1  2401  Borderlands   Positive
# 2  2401  Borderlands   Positive
# 3  2401  Borderlands   Positive
#
#                                                 text  Unnamed: 4  Unnamed: 5  \
# 0  im getting on borderlands and i will murder yo...         NaN         NaN
# 1  I am coming to the borders and I will kill you...         NaN         NaN
# 2  im getting on borderlands and i will kill you ...         NaN         NaN
# 3  im coming on borderlands and i will murder you...         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN

# %%
T_data['game_titles'].value_counts()
# Out:
# TomClancysRainbowSix                 2400
# MaddenNFL                            2400
# Microsoft                            2400
# LeagueOfLegends                      2394
# CallOfDuty                           2394
# Verizon                              2382
# CallOfDutyBlackopsColdWar            2376
# ApexLegends                          2376
# Facebook                             2370
# WorldOfCraft                         2364
# Dota2                                2364
# NBA2K                                2352
# TomClancysGhostRecon                 2346
# Battlefield                          2346
# FIFA                                 2340
# Xbox(Xseries)                        2334
# Overwatch                            2334
# johnson&johnson                      2328
# Amazon                               2316
# PlayStation5(PS5)                    2310
# HomeDepot                            2310
# Cyberpunk2077                        2304
# ...

# %%
T_data.shape
# Out:
# (74682, 8)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
T_data['sentiments']=encoder.fit_transform(T_data['sentiments'])
T_data['sentiments']
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 74677    3
# 74678    3
# 74679    3
# 74680    3
# 74681    3
# Name: sentiments, Length: 74682, dtype: int64

# %%
T_data['sentiments'].value_counts()
# Out:
# 1    22542
# 3    20832
# 2    18318
# 0    12990
# Name: sentiments, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(T_data['sentiments'].value_counts(),labels=['Negative','Positive','Neutral','Irrelavant'],autopct="%0.2f")
plt.show()

# %%
print(T_data.shape)
# Out:
# (74682, 8)

# %%
T_data.head()
# Out:
#      id  game_titles  sentiments  \
# 0  2401  Borderlands           3
# 1  2401  Borderlands           3
# 2  2401  Borderlands           3
# 3  2401  Borderlands           3
# 4  2401  Borderlands           3
#
#                                                 text  Unnamed: 4  Unnamed: 5  \
# 0  im getting on borderlands and i will murder yo...         NaN         NaN
# 1  I am coming to the borders and I will kill you...         NaN         NaN
# 2  im getting on borderlands and i will kill you ...         NaN         NaN
# 3  im coming on borderlands and i will murder you...         NaN         NaN
# 4  im getting on borderlands 2 and i will murder ...         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %% [markdown]
# **3. Data preprocessing**
#
# Lower case
#
# Tokenization
#
# Removing special characters
#
# Removing drop words and puctuation
#
# Stemming

# %%
import nltk
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()
import string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import string
from nltk.corpus import stopwords
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)


    text=y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))

    return " ".join(y)

# %%
from wordcloud import WordCloud
wc= WordCloud(width=500, height=500, min_font_size=10, background_color='white')

# %%
Irrelavant_wc= wc.generate(T_data[T_data['sentiments']== 0]['text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(Irrelavant_wc)

# %%
Neutral_wc= wc.generate(T_data[T_data['sentiments']== 3]['text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(Neutral_wc)

# %%
Negative_wc= wc.generate(T_data[T_data['sentiments']== 1]['text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(Negative_wc)

# %%
T_data.head()
# Out:
#      id  game_titles  sentiments  \
# 0  2401  Borderlands           3
# 1  2401  Borderlands           3
# 2  2401  Borderlands           3
# 3  2401  Borderlands           3
# 4  2401  Borderlands           3
#
#                                                 text  Unnamed: 4  Unnamed: 5  \
# 0  im getting on borderlands and i will murder yo...         NaN         NaN
# 1  I am coming to the borders and I will kill you...         NaN         NaN
# 2  im getting on borderlands and i will kill you ...         NaN         NaN
# 3  im coming on borderlands and i will murder you...         NaN         NaN
# 4  im getting on borderlands 2 and i will murder ...         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
